# %%
print("foo")

# %%
cube();

# %%
$fn = 100;
r = 10;
h = 20;

module lobe() {
hull() {
    translate([0,0,20]) sphere(r = r);
    sphere(r = 0.1);
    translate([0,-10,10]) sphere(r = r*.71);
}
}


module heart() {
    rotate([-22.5,0,0]) lobe();
    rotate([22.5,0,0]) mirror([0,1,0]) lobe();
}
